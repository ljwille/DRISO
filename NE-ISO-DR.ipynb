# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as md
from palettable.colorbrewer.qualitative import Dark2_8

from datetime import date
import datetime
# %matplotlib inline

# %%
x = pd.read_csv("ISOdata/drtpdetail_20170801.csv",skiprows=[0,1,2,3,5],usecols=[1,2,3,4],skipfooter=1, sep=',')
y = pd.read_csv("ISOdata/drtpsummary_20110924.csv",skiprows=[0,1,2,3,5],usecols=range(1,12),skipfooter=1,sep=',')
# Out:
# /home/logan/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.
# /home/logan/.local/lib/python2.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.

# %%
x.plot(x="Offer MW",y="Offer Price")

# %%
y.plot(x="Trading Month",y="Demand Reduction Threshold Price")
